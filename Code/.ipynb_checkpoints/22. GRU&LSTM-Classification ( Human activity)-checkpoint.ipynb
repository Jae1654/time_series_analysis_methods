# %%
from tensorflow.keras.layers import Input, SimpleRNN, Dense, Flatten, GlobalMaxPooling1D, LSTM, GRU, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf
from sklearn.preprocessing import StandardScaler

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import mean_absolute_percentage_error

# %%
T = 128
Ntrain = 7352
Ntest = 2947
D = 9 # 9 files
K = 6 # 6 Classes


def load_data():
    # returns:
    # Xtrain (Ntrain x T x D), Ytrain (Ntrain)
    # Xtest (Ntest x T x D), Ytest (Ntest)
    
    Xtrain = np.zeros((Ntrain, T, D))
    Xtest = np.zeros((Ntest, T, D))
    
    
    
    ##### train data
    ts_filenames = [
        'body_acc_x_train.txt', 'body_gyro_x_train.txt', 'total_acc_x_train.txt',
        'body_acc_y_train.txt', 'body_gyro_y_train.txt', 'total_acc_y_train.txt',
        'body_acc_z_train.txt', 'body_gyro_z_train.txt', 'total_acc_z_train.txt'
    ]
    
    ts_file_prefix = '../Data/UCI HAR Dataset/train/'
    
    for d, fn in enumerate(ts_filenames):
        df = pd.read_csv(
            f'{ts_file_prefix}Inertial Signals/{fn}',
            header = None,
            delim_whitespace = True
        )
        
        # Ntrain x T array
        x = df.to_numpy()
        Xtrain[:, :, d] = x
        
    
    # train labels
    Ytrain = pd.read_csv(
        f'{ts_file_prefix}y_train.txt',
            header = None).to_numpy() -1
    Ytrain = Ytrain.flatten()
    
    
    
    ##### test data
    ts_filenames = [
        'body_acc_x_test.txt', 'body_gyro_x_test.txt', 'total_acc_x_test.txt',
        'body_acc_y_test.txt', 'body_gyro_y_test.txt', 'total_acc_y_test.txt',
        'body_acc_z_test.txt', 'body_gyro_z_test.txt', 'total_acc_z_test.txt'
    ]
    ts_file_prefix = '../Data/UCI HAR Dataset/test/'

    for d, fn in enumerate(ts_filenames):
        df = pd.read_csv(
            f'{ts_file_prefix}Inertial Signals/{fn}',
            header = None,
            delim_whitespace = True
        )
        
        # Ntest x T array
        x = df.to_numpy()
        Xtest[:, :, d] = x
        
    # test labels
    Ytest = pd.read_csv(
        f'{ts_file_prefix}y_test.txt',
            header = None).to_numpy() -1
    Ytest = Ytest.flatten()
    
    
    return Xtrain, Ytrain, Xtest, Ytest

# %%
Xtrain, Ytrain, Xtest, Ytest = load_data()

# %% [markdown]
# # LSTM model

# %%
# Make an RNN
i = Input(shape = (T, D))
x = LSTM(32, return_sequences = True)(i)
x = GlobalMaxPooling1D()(x)
x = Dense(K)(x)

model = Model(i, x)

# %%
# To save the best model
check_point = ModelCheckpoint(
    'best_model.h5', monitor = 'val_loss', save_best_only = True)

# %%
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 128, 9)]          0
#
#  lstm_4 (LSTM)               (None, 128, 32)           5376
#
#  global_max_pooling1d_1 (Glo  (None, 32)               0
#  balMaxPooling1D)
#
#  dense_3 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 5,574
# Trainable params: 5,574
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    loss = SparseCategoricalCrossentropy(from_logits = True),
    optimizer = 'adam',
    metrics = ['accuracy']
)

r = model.fit(
    Xtrain,
    Ytrain,
    epochs = 100,
    validation_data = (Xtest, Ytest)
    )
# Out:
# Epoch 1/100
# 230/230 [==============================] - 7s 26ms/step - loss: 1.0814 - accuracy: 0.7031 - val_loss: 0.6919 - val_accuracy: 0.8551
# Epoch 2/100
# 230/230 [==============================] - 6s 25ms/step - loss: 0.4481 - accuracy: 0.9002 - val_loss: 0.4345 - val_accuracy: 0.8755
# Epoch 3/100
# 230/230 [==============================] - 6s 24ms/step - loss: 0.2655 - accuracy: 0.9245 - val_loss: 0.3638 - val_accuracy: 0.8714
# Epoch 4/100
# 230/230 [==============================] - 6s 25ms/step - loss: 0.2004 - accuracy: 0.9376 - val_loss: 0.3476 - val_accuracy: 0.8761
# Epoch 5/100
# 230/230 [==============================] - 6s 25ms/step - loss: 0.1652 - accuracy: 0.9457 - val_loss: 0.3281 - val_accuracy: 0.8785
# Epoch 6/100
# 230/230 [==============================] - 6s 24ms/step - loss: 0.1623 - accuracy: 0.9459 - val_loss: 0.2847 - val_accuracy: 0.8931
# Epoch 7/100
# 230/230 [==============================] - 6s 24ms/step - loss: 0.1420 - accuracy: 0.9531 - val_loss: 0.2515 - val_accuracy: 0.9043
# Epoch 8/100
# 230/230 [==============================] - 6s 24ms/step - loss: 0.1304 - accuracy: 0.9551 - val_loss: 0.2638 - val_accuracy: 0.8979
# Epoch 9/100
# 230/230 [==============================] - 6s 25ms/step - loss: 0.1919 - accuracy: 0.9357 - val_loss: 0.2459 - val_accuracy: 0.9118
# Epoch 10/100
# 230/230 [==============================] - 6s 24ms/step - loss: 0.1419 - accuracy: 0.9510 - val_loss: 0.2454 - val_accuracy: 0.9111
# Epoch 11/100
# 230/230 [==============================] - 6s 25ms/step - loss: 0.1235 - accuracy: 0.9546 - val_loss: 0.2277 - val_accuracy: 0.9070
# Epoch 12/100
# 230/230 [==============================] - 6s 24ms/step - loss: 0.1218 - accuracy: 0.9529 - val_loss: 0.2320 - val_accuracy: 0.9077
# Epoch 13/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.1166 - accuracy: 0.9563 - val_loss: 0.2411 - val_accuracy: 0.9080
# Epoch 14/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.1148 - accuracy: 0.9558 - val_loss: 0.2562 - val_accuracy: 0.9070
# Epoch 15/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.1123 - accuracy: 0.9563 - val_loss: 0.2548 - val_accuracy: 0.9036
# Epoch 16/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.1127 - accuracy: 0.9544 - val_loss: 0.2528 - val_accuracy: 0.9060
# Epoch 17/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.1102 - accuracy: 0.9585 - val_loss: 0.2621 - val_accuracy: 0.9050
# Epoch 18/100
# 230/230 [==============================] - 6s 24ms/step - loss: 0.1090 - accuracy: 0.9574 - val_loss: 0.2445 - val_accuracy: 0.9074
# Epoch 19/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.1279 - accuracy: 0.9528 - val_loss: 0.2512 - val_accuracy: 0.9074
# Epoch 20/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.1085 - accuracy: 0.9573 - val_loss: 0.2418 - val_accuracy: 0.9108
# Epoch 21/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.1230 - accuracy: 0.9508 - val_loss: 0.2151 - val_accuracy: 0.9175
# Epoch 22/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.1066 - accuracy: 0.9578 - val_loss: 0.2465 - val_accuracy: 0.9077
# Epoch 23/100
# 230/230 [==============================] - 6s 24ms/step - loss: 0.1126 - accuracy: 0.9539 - val_loss: 0.2702 - val_accuracy: 0.9050
# Epoch 24/100
# 230/230 [==============================] - 6s 24ms/step - loss: 0.1104 - accuracy: 0.9587 - val_loss: 0.2171 - val_accuracy: 0.9138
# Epoch 25/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.1070 - accuracy: 0.9554 - val_loss: 0.2072 - val_accuracy: 0.9199
# Epoch 26/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.1089 - accuracy: 0.9580 - val_loss: 0.2176 - val_accuracy: 0.9141
# Epoch 27/100
# 230/230 [==============================] - 6s 24ms/step - loss: 0.1046 - accuracy: 0.9587 - val_loss: 0.2246 - val_accuracy: 0.9108
# Epoch 28/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.1037 - accuracy: 0.9574 - val_loss: 0.2237 - val_accuracy: 0.9091
# Epoch 29/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.1008 - accuracy: 0.9599 - val_loss: 0.2306 - val_accuracy: 0.9192
# Epoch 30/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.0991 - accuracy: 0.9597 - val_loss: 0.2328 - val_accuracy: 0.9179
# Epoch 31/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.1009 - accuracy: 0.9595 - val_loss: 0.2274 - val_accuracy: 0.9179
# Epoch 32/100
# 230/230 [==============================] - 6s 24ms/step - loss: 0.0966 - accuracy: 0.9604 - val_loss: 0.2401 - val_accuracy: 0.9162
# Epoch 33/100
# 230/230 [==============================] - 6s 24ms/step - loss: 0.0978 - accuracy: 0.9601 - val_loss: 0.2484 - val_accuracy: 0.9145
# Epoch 34/100
# 230/230 [==============================] - 6s 24ms/step - loss: 0.0978 - accuracy: 0.9595 - val_loss: 0.2671 - val_accuracy: 0.9080
# Epoch 35/100
# 230/230 [==============================] - 6s 24ms/step - loss: 0.0966 - accuracy: 0.9601 - val_loss: 0.2723 - val_accuracy: 0.9043
# Epoch 36/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0969 - accuracy: 0.9614 - val_loss: 0.2271 - val_accuracy: 0.9145
# Epoch 37/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.1076 - accuracy: 0.9599 - val_loss: 0.2303 - val_accuracy: 0.9182
# Epoch 38/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0946 - accuracy: 0.9619 - val_loss: 0.2866 - val_accuracy: 0.9040
# Epoch 39/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0914 - accuracy: 0.9614 - val_loss: 0.2576 - val_accuracy: 0.9087
# Epoch 40/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.1052 - accuracy: 0.9561 - val_loss: 0.2677 - val_accuracy: 0.8996
# Epoch 41/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.1035 - accuracy: 0.9555 - val_loss: 0.2485 - val_accuracy: 0.9040
# Epoch 42/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0949 - accuracy: 0.9603 - val_loss: 0.2533 - val_accuracy: 0.9104
# Epoch 43/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0914 - accuracy: 0.9622 - val_loss: 0.2516 - val_accuracy: 0.9152
# Epoch 44/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0882 - accuracy: 0.9623 - val_loss: 0.2604 - val_accuracy: 0.9175
# Epoch 45/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0987 - accuracy: 0.9599 - val_loss: 0.2410 - val_accuracy: 0.9165
# Epoch 46/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0935 - accuracy: 0.9615 - val_loss: 0.2391 - val_accuracy: 0.9233
# Epoch 47/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0892 - accuracy: 0.9637 - val_loss: 0.2617 - val_accuracy: 0.9138
# Epoch 48/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.0892 - accuracy: 0.9612 - val_loss: 0.2405 - val_accuracy: 0.9274
# Epoch 49/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.0832 - accuracy: 0.9637 - val_loss: 0.2950 - val_accuracy: 0.9138
# Epoch 50/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.0880 - accuracy: 0.9616 - val_loss: 0.2710 - val_accuracy: 0.9125
# Epoch 51/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.0868 - accuracy: 0.9653 - val_loss: 0.2772 - val_accuracy: 0.9077
# Epoch 52/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.0832 - accuracy: 0.9648 - val_loss: 0.2887 - val_accuracy: 0.9108
# Epoch 53/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.0811 - accuracy: 0.9638 - val_loss: 0.2572 - val_accuracy: 0.9277
# Epoch 54/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.0799 - accuracy: 0.9659 - val_loss: 0.2836 - val_accuracy: 0.9175
# Epoch 55/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.0808 - accuracy: 0.9648 - val_loss: 0.2875 - val_accuracy: 0.9118
# Epoch 56/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.0855 - accuracy: 0.9642 - val_loss: 0.2922 - val_accuracy: 0.9094
# Epoch 57/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0796 - accuracy: 0.9648 - val_loss: 0.2656 - val_accuracy: 0.9257
# Epoch 58/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0801 - accuracy: 0.9659 - val_loss: 0.2907 - val_accuracy: 0.9192
# Epoch 59/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0802 - accuracy: 0.9657 - val_loss: 0.3414 - val_accuracy: 0.9067
# Epoch 60/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0892 - accuracy: 0.9650 - val_loss: 0.2795 - val_accuracy: 0.9165
# Epoch 61/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0798 - accuracy: 0.9648 - val_loss: 0.2840 - val_accuracy: 0.9097
# Epoch 62/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0752 - accuracy: 0.9680 - val_loss: 0.2893 - val_accuracy: 0.9104
# Epoch 63/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0743 - accuracy: 0.9687 - val_loss: 0.2954 - val_accuracy: 0.9104
# Epoch 64/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0885 - accuracy: 0.9623 - val_loss: 0.3195 - val_accuracy: 0.9043
# Epoch 65/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0804 - accuracy: 0.9672 - val_loss: 0.2565 - val_accuracy: 0.9199
# Epoch 66/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0775 - accuracy: 0.9672 - val_loss: 0.2976 - val_accuracy: 0.9158
# Epoch 67/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0750 - accuracy: 0.9687 - val_loss: 0.3176 - val_accuracy: 0.9057
# Epoch 68/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0732 - accuracy: 0.9699 - val_loss: 0.3298 - val_accuracy: 0.8999
# Epoch 69/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0725 - accuracy: 0.9693 - val_loss: 0.3203 - val_accuracy: 0.9135
# Epoch 70/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0708 - accuracy: 0.9682 - val_loss: 0.3137 - val_accuracy: 0.9043
# Epoch 71/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0696 - accuracy: 0.9718 - val_loss: 0.3023 - val_accuracy: 0.9121
# Epoch 72/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0844 - accuracy: 0.9630 - val_loss: 0.3087 - val_accuracy: 0.8982
# Epoch 73/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0771 - accuracy: 0.9667 - val_loss: 0.2821 - val_accuracy: 0.9165
# Epoch 74/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0735 - accuracy: 0.9679 - val_loss: 0.3119 - val_accuracy: 0.9080
# Epoch 75/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0724 - accuracy: 0.9694 - val_loss: 0.3188 - val_accuracy: 0.9063
# Epoch 76/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0682 - accuracy: 0.9716 - val_loss: 0.3034 - val_accuracy: 0.9155
# Epoch 77/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0825 - accuracy: 0.9644 - val_loss: 0.2776 - val_accuracy: 0.8979
# Epoch 78/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0792 - accuracy: 0.9682 - val_loss: 0.2881 - val_accuracy: 0.9046
# Epoch 79/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0719 - accuracy: 0.9702 - val_loss: 0.2986 - val_accuracy: 0.8968
# Epoch 80/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0715 - accuracy: 0.9684 - val_loss: 0.2852 - val_accuracy: 0.9074
# Epoch 81/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0690 - accuracy: 0.9708 - val_loss: 0.2923 - val_accuracy: 0.9104
# Epoch 82/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0634 - accuracy: 0.9728 - val_loss: 0.3287 - val_accuracy: 0.9053
# Epoch 83/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0645 - accuracy: 0.9723 - val_loss: 0.3046 - val_accuracy: 0.9118
# Epoch 84/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0605 - accuracy: 0.9752 - val_loss: 0.3538 - val_accuracy: 0.9063
# Epoch 85/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0626 - accuracy: 0.9736 - val_loss: 0.2974 - val_accuracy: 0.9148
# Epoch 86/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0578 - accuracy: 0.9752 - val_loss: 0.3387 - val_accuracy: 0.9128
# Epoch 87/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0595 - accuracy: 0.9773 - val_loss: 0.3012 - val_accuracy: 0.9087
# Epoch 88/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0551 - accuracy: 0.9771 - val_loss: 0.3238 - val_accuracy: 0.9101
# Epoch 89/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0601 - accuracy: 0.9755 - val_loss: 0.3544 - val_accuracy: 0.8996
# Epoch 90/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0691 - accuracy: 0.9731 - val_loss: 0.3190 - val_accuracy: 0.9060
# Epoch 91/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0595 - accuracy: 0.9771 - val_loss: 0.3269 - val_accuracy: 0.9114
# Epoch 92/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0547 - accuracy: 0.9780 - val_loss: 0.3371 - val_accuracy: 0.9097
# Epoch 93/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0540 - accuracy: 0.9781 - val_loss: 0.3408 - val_accuracy: 0.9114
# Epoch 94/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0498 - accuracy: 0.9789 - val_loss: 0.3115 - val_accuracy: 0.9172
# Epoch 95/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0485 - accuracy: 0.9819 - val_loss: 0.3227 - val_accuracy: 0.9097
# Epoch 96/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0526 - accuracy: 0.9782 - val_loss: 0.3286 - val_accuracy: 0.9077
# Epoch 97/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0511 - accuracy: 0.9786 - val_loss: 0.3190 - val_accuracy: 0.9148
# Epoch 98/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0713 - accuracy: 0.9698 - val_loss: 0.3605 - val_accuracy: 0.8687
# Epoch 99/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.1022 - accuracy: 0.9580 - val_loss: 0.2818 - val_accuracy: 0.9111
# Epoch 100/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0883 - accuracy: 0.9648 - val_loss: 0.2804 - val_accuracy: 0.9104

# %%
plt.plot(r.history['loss'], label = 'train loss')
plt.plot(r.history['val_loss'], label = 'test loss')
plt.legend();

# %%
plt.plot(r.history['accuracy'], label = 'train loss')
plt.plot(r.history['accuracy'], label = 'test loss')
plt.legend();

# %%
# Load the best model
best_model = tf.keras.models.load_model('best_model.h5')

# make predictions
Ptest = best_model.predict(Xtest)

# evauluate
np.mean(np.argmax(Ptest, axis = 1) == Ytest)
# Out:
# 93/93 [==============================] - 1s 4ms/step
# 0.9226331862911435

# %%
def load_features():
    df = pd.read_csv(
        '../Data/UCI HAR Dataset/train/X_train.txt',
        header = None,
        delim_whitespace = True
    )
    
    feat_train = df.to_numpy()
    
    # test data
    df = pd.read_csv(
        '../Data/UCI HAR Dataset/test/X_test.txt',
        header = None,
        delim_whitespace = True
    )
    feat_test = df.to_numpy()
    
    scaler = StandardScaler()
    feat_train = scaler.fit_transform(feat_train)
    feat_test = scaler.transform(feat_test)
    
    return feat_train, feat_test


feat_train, feat_test = load_features()

D_feat = feat_train.shape[1]

# %% [markdown]
# # Combined RNN

# %%
# Make an RNN
i = Input(shape = (T, D))
x = LSTM(32, return_sequences = True)(i)
x = GlobalMaxPooling1D()(x)

# ANN
i2 = Input(shape = (D_feat,))
x2 = Dense(32, activation = 'relu')(i2)

x = Concatenate()([x, x2])
x = Dense(K)(x)

model = Model([i, i2], x)

# %%
tf.keras.utils.plot_model(model)

# %%
# To save the best model
check_point = ModelCheckpoint(
    'best_model_combined.h5', monitor = 'val_accuracy', save_best_only = True)

# %%
model.compile(
    loss = SparseCategoricalCrossentropy(from_logits = True),
    optimizer = 'adam',
    metrics = ['accuracy']
)

r = model.fit(
    [Xtrain, feat_train],
    Ytrain,
    epochs = 15,
    callbacks = [check_point],
    validation_data = ([Xtest, feat_test], Ytest)
    )
# Out:
# Epoch 1/15
# 230/230 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9937WARNING:tensorflow:Can save best model only with val_accuracyZ available, skipping.
# 230/230 [==============================] - 7s 27ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 0.2321 - val_accuracy: 0.9352
# Epoch 2/15
# 228/230 [============================>.] - ETA: 0s - loss: 0.0178 - accuracy: 0.9933WARNING:tensorflow:Can save best model only with val_accuracyZ available, skipping.
# 230/230 [==============================] - 6s 25ms/step - loss: 0.0180 - accuracy: 0.9932 - val_loss: 0.2502 - val_accuracy: 0.9338
# Epoch 3/15
# 229/230 [============================>.] - ETA: 0s - loss: 0.0136 - accuracy: 0.9954WARNING:tensorflow:Can save best model only with val_accuracyZ available, skipping.
# 230/230 [==============================] - 6s 26ms/step - loss: 0.0136 - accuracy: 0.9954 - val_loss: 0.2535 - val_accuracy: 0.9382
# Epoch 4/15
# 228/230 [============================>.] - ETA: 0s - loss: 0.0086 - accuracy: 0.9977WARNING:tensorflow:Can save best model only with val_accuracyZ available, skipping.
# 230/230 [==============================] - 6s 25ms/step - loss: 0.0086 - accuracy: 0.9977 - val_loss: 0.2456 - val_accuracy: 0.9396
# Epoch 5/15
# 229/230 [============================>.] - ETA: 0s - loss: 0.0091 - accuracy: 0.9973WARNING:tensorflow:Can save best model only with val_accuracyZ available, skipping.
# 230/230 [==============================] - 6s 26ms/step - loss: 0.0091 - accuracy: 0.9973 - val_loss: 0.2247 - val_accuracy: 0.9399
# Epoch 6/15
# 230/230 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9978WARNING:tensorflow:Can save best model only with val_accuracyZ available, skipping.
# 230/230 [==============================] - 6s 25ms/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.2501 - val_accuracy: 0.9386
# Epoch 7/15
# 228/230 [============================>.] - ETA: 0s - loss: 0.0082 - accuracy: 0.9977WARNING:tensorflow:Can save best model only with val_accuracyZ available, skipping.
# 230/230 [==============================] - 6s 26ms/step - loss: 0.0082 - accuracy: 0.9977 - val_loss: 0.2235 - val_accuracy: 0.9437
# Epoch 8/15
# 230/230 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9967WARNING:tensorflow:Can save best model only with val_accuracyZ available, skipping.
# 230/230 [==============================] - 6s 28ms/step - loss: 0.0111 - accuracy: 0.9967 - val_loss: 0.2468 - val_accuracy: 0.9359
# Epoch 9/15
# 230/230 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9963WARNING:tensorflow:Can save best model only with val_accuracyZ available, skipping.
# 230/230 [==============================] - 6s 26ms/step - loss: 0.0119 - accuracy: 0.9963 - val_loss: 0.2981 - val_accuracy: 0.9291
# Epoch 10/15
# 229/230 [============================>.] - ETA: 0s - loss: 0.0097 - accuracy: 0.9970WARNING:tensorflow:Can save best model only with val_accuracyZ available, skipping.
# 230/230 [==============================] - 6s 25ms/step - loss: 0.0098 - accuracy: 0.9969 - val_loss: 0.3035 - val_accuracy: 0.9287
# Epoch 11/15
# 228/230 [============================>.] - ETA: 0s - loss: 0.0048 - accuracy: 0.9989WARNING:tensorflow:Can save best model only with val_accuracyZ available, skipping.
# 230/230 [==============================] - 6s 26ms/step - loss: 0.0047 - accuracy: 0.9989 - val_loss: 0.2802 - val_accuracy: 0.9382
# Epoch 12/15
# 229/230 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9996WARNING:tensorflow:Can save best model only with val_accuracyZ available, skipping.
# 230/230 [==============================] - 6s 26ms/step - loss: 0.0034 - accuracy: 0.9996 - val_loss: 0.2430 - val_accuracy: 0.9406
# Epoch 13/15
# 229/230 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9999WARNING:tensorflow:Can save best model only with val_accuracyZ available, skipping.
# 230/230 [==============================] - 6s 25ms/step - loss: 0.0023 - accuracy: 0.9999 - val_loss: 0.2546 - val_accuracy: 0.9406
# Epoch 14/15
# 230/230 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracyZ available, skipping.
# 230/230 [==============================] - 6s 25ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2824 - val_accuracy: 0.9386
# Epoch 15/15
# 230/230 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9990WARNING:tensorflow:Can save best model only with val_accuracyZ available, skipping.
# 230/230 [==============================] - 6s 25ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.5299 - val_accuracy: 0.9111

# %%
plt.plot(r.history['loss'], label = 'train loss')
plt.plot(r.history['val_loss'], label = 'test loss')
plt.legend();

# %%
plt.plot(r.history['accuracy'], label = 'train loss')
plt.plot(r.history['accuracy'], label = 'test loss')
plt.legend();

# %%
# Load the best model
best_model = tf.keras.models.load_model('best_model_combined.h5')

# make predictions
Ptest = best_model.predict([Xtest, feat_test])

# evauluate
np.mean(np.argmax(Ptest, axis = 1) == Ytest.flatten())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 5
#       2 best_model = tf.keras.models.load_model('best_model_combined.h5')
#       4 # make predictions
# ----> 5 Ptest = best_model.predict(feat_test)
#       7 # evauluate
#       8 np.mean(np.argmax(Ptest, axis = 1) == Ytest)
#
# File ~/miniconda3/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /var/folders/09/t5f173_57wj_mzwtx_28y9y80000gn/T/__autograph_generated_file_k9lpq_e.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "/Users/yunjaecho/miniconda3/lib/python3.10/site-packages/keras/engine/training.py", line 2169, in predict_function  *
#         return step_function(self, iterator)
#     File "/Users/yunjaecho/miniconda3/lib/python3.10/site-packages/keras/engine/training.py", line 2155, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/yunjaecho/miniconda3/lib/python3.10/site-packages/keras/engine/training.py", line 2143, in run_step  **
#         outputs = model.predict_step(data)
#     File "/Users/yunjaecho/miniconda3/lib/python3.10/site-packages/keras/engine/training.py", line 2111, in predict_step
#         return self(x, training=False)
#     File "/Users/yunjaecho/miniconda3/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/yunjaecho/miniconda3/lib/python3.10/site-packages/keras/engine/input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "model_2" is incompatible with the layer: expected shape=(None, 128, 9), found shape=(None, 561)
