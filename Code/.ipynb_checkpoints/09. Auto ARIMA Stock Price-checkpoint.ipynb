# %%
#!pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.3-cp310-cp310-macosx_11_0_arm64.whl (579 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 579.2/579.2 kB 9.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: joblib>=0.11 in /Users/yunjaecho/Git/env/lib/python3.10/site-packages (from pmdarima) (1.3.2)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29 (from pmdarima)
#   Obtaining dependency information for Cython!=0.29.18,!=0.29.31,>=0.29 from https://files.pythonhosted.org/packages/03/e9/9cc0c4f0d8a566089d096254cd25168a0db02dd047863a7f995d8d3eefa7/Cython-3.0.2-py2.py3-none-any.whl.metadata
#   Downloading Cython-3.0.2-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy>=1.21.2 in /Users/yunjaecho/Git/env/lib/python3.10/site-packages (from pmdarima) (1.26.0)
# Requirement already satisfied: pandas>=0.19 in /Users/yunjaecho/Git/env/lib/python3.10/site-packages (from pmdarima) (2.1.1)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/yunjaecho/Git/env/lib/python3.10/site-packages (from pmdarima) (1.3.1)
# Requirement already satisfied: scipy>=1.3.2 in /Users/yunjaecho/Git/env/lib/python3.10/site-packages (from pmdarima) (1.11.3)
# Requirement already satisfied: statsmodels>=0.13.2 in /Users/yunjaecho/Git/env/lib/python3.10/site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in /Users/yunjaecho/Git/env/lib/python3.10/site-packages (from pmdarima) (2.0.5)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/yunjaecho/Git/env/lib/python3.10/site-packages (from pmdarima) (68.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/yunjaecho/Git/env/lib/python3.10/site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/yunjaecho/Git/env/lib/python3.10/site-packages (from pandas>=0.19->pmdarima) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/yunjaecho/Git/env/lib/python3.10/site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/yunjaecho/Git/env/lib/python3.10/site-packages (from scikit-learn>=0.22->pmdarima) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /Users/yunjaecho/Git/env/lib/python3.10/site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /Users/yunjaecho/Git/env/lib/python3.10/site-packages (from statsmodels>=0.13.2->pmdarima) (23.2)
# Requirement already satisfied: six in /Users/yunjaecho/Git/env/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Downloading Cython-3.0.2-py2.py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: Cython, pmdarima
# Successfully installed Cython-3.0.2 pmdarima-2.0.3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import pmdarima as pm

# %%
df = pd.read_csv("../Data/sp500sub.csv",
                 index_col = 'Date',
                 parse_dates = True)
goog = df[df['Name'] == 'GOOG'][['Close']].copy()
goog.plot(figsize = (20, 8))
# Out:
# <Axes: xlabel='Date'>

# %%
Ntest = 30
train = goog.iloc[:-Ntest]
test = goog.iloc[-Ntest:]

# %%
model = pm.auto_arima(train,
                     trace = True,
                     suppress_warnings = True,
                     seasonal = False)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=16241.679, Time=0.94 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=16270.383, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=16269.726, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=16269.492, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=16271.123, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=16268.065, Time=0.32 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=16267.873, Time=0.26 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=16241.135, Time=0.97 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=16266.968, Time=0.32 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=16243.486, Time=1.29 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=16244.644, Time=1.29 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=16241.210, Time=1.13 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=16255.943, Time=0.81 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=16242.147, Time=1.38 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=16241.737, Time=0.55 sec
#
# Best model:  ARIMA(3,1,2)(0,0,0)[0] intercept
# Total fit time: 9.409 seconds

# %%
def plot_result(model, fulldata, train, test):
    params = model.get_params()
    d = params['order'][1] # get differencing order
    
    train_pred = model.predict_in_sample(start = d, end = -1)
    test_pred, confint = model.predict(n_periods = Ntest, return_conf_int = True)
    
    fig, ax = plt.subplots(figsize = (10, 5))
    ax.plot(fulldata.index, fulldata, label = 'data')
    ax.plot(train.index[d:], train_pred, label = 'fitted')
    ax.plot(test.index, test_pred , label = 'forecast')
    ax.fill_between(test.index, \
                   confint[:,0], confint[:,1], \
                   color = 'red', alpha = 0.3)
    ax.legend();

    
plot_result(model, goog, train, test)
# Out:
# /Users/yunjaecho/miniconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/yunjaecho/miniconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
def plot_test(model, test):

    test_pred, confint = model.predict(n_periods = Ntest, return_conf_int = True)
    
    fig, ax = plt.subplots(figsize = (10, 5))
    ax.plot(test.index, test , label = 'true')
    ax.plot(test.index, test_pred , label = 'forecast')
    ax.fill_between(test.index, \
                   confint[:,0], confint[:,1], \
                   color = 'red', alpha = 0.3)
    ax.legend();
    
    
plot_test(model, test)
# Out:
# /Users/yunjaecho/miniconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/yunjaecho/miniconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
model.predict(Ntest)
# Out:
# /Users/yunjaecho/miniconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/yunjaecho/miniconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# 2233    1036.020919
# 2234    1031.157469
# 2235    1035.143421
# 2236    1037.832063
# 2237    1033.003944
# 2238    1034.714572
# 2239    1038.988178
# 2240    1035.214497
# 2241    1034.669082
# 2242    1039.527157
# 2243    1037.494372
# 2244    1035.163665
# 2245    1039.619173
# 2246    1039.573995
# 2247    1036.225996
# 2248    1039.501971
# 2249    1041.259321
# 2250    1037.766012
# 2251    1039.424241
# 2252    1042.460946
# 2253    1039.609418
# 2254    1039.594198
# 2255    1043.198393
# 2256    1041.543745
# 2257    1040.143026
# 2258    1043.581926
# 2259    1043.366050
# 2260    1041.108590
# 2261    1043.778521
# 2262    1044.922463
# dtype: float64

# %%
def rmse(t, y):
    return np.sqrt(np.mean((t - y)**2))

print("RMSE ARIMA", rmse(model.predict(Ntest).values, test['Close']))
print("RMSE Naive", rmse(train.iloc[-1], test))
# Out:
# RMSE ARIMA 30.857217121240133
# RMSE Naive 30.029502477261467
# /Users/yunjaecho/miniconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/yunjaecho/miniconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
